# %%
# extractor.py

import re
import pdfplumber
import pandas as pd
import numpy as np
from typing import List, Dict, Any, Optional, Tuple
from tabulate import tabulate

# Import everything from config at once—our static methods will refer to config.<CONSTANT>
import config


class BBLStatementExtractor:
    """
    Extract headers and transactions from a BBL PDF statement.

    All helper methods are @staticmethod.  Only run() accepts
    a pdf_path and password as arguments.
    """

    # Compile regexes once at the class level so static methods can use them:
    _date_regex = re.compile(config.DATE_REGEX_PATTERN)
    _time_regex = re.compile(config.TIME_REGEX_PATTERN)
    _money_regex = re.compile(config.MONEY_REGEX_PATTERN)
    _page_regex = re.compile(config.PAGE_REGEX_PATTERN)

    @staticmethod
    def extract_page_id(page: pdfplumber.page.Page) -> str:
        """
        Crop and parse the page ID for pagination like '1/5'.
        Relies on config.PAGE_REGEX_PATTERN to find something like '1/5' at the bottom.
        """
        try:
            width, height = page.width, page.height
            # coordinates: (x0, y0, x1, y1)
            crop_box = (width - 180, height - 25, width, height)
            raw_text = page.crop(crop_box).extract_text() or ""
            single_line = raw_text.replace("\n", " ")
            match = BBLStatementExtractor._page_regex.search(single_line)
            return f"{match.group(1)}/{match.group(2)}" if match else ""
        except Exception:
            return ""

    @staticmethod
    def extract_headers(pages: List[pdfplumber.page.Page]) -> List[Dict[str, Any]]:
        """
        Extract header information from each page.
        Each page is cropped at various boxes (config.CROPS) to pull out fields
        like account number, statement date, etc.  Then look for FOOTER_KEYS
        (e.g. "จํานวนรายการถอน" / "จํานวนรายการฝาก") to grab totals.
        """
        header_records: List[Dict[str, Any]] = []

        for page in pages:
            page_id = BBLStatementExtractor.extract_page_id(page)
            try:
                full_text = page.extract_text() or ""
                record: Dict[str, Any] = {"page_id": page_id}

                # For each field defined in config.CROPS, crop and strip text.
                for field_name, box in config.CROPS.items():
                    text = page.crop(box).extract_text() or ""
                    record[field_name] = text.strip().replace("\n", " ")

                # If any of the FOOTER_KEYS appear in the page text, parse totals.
                if any(key in full_text for key in config.FOOTER_KEYS):
                    for line in full_text.splitlines():
                        if line.startswith("จํานวนรายการถอน"):
                            numbers = re.findall(r"[\d,]+(?:\.\d{2})?", line)
                            record["total_withdrawal_transaction"] = (
                                float(numbers[0].replace(",", "")) if len(numbers) > 0 else None
                            )
                            record["total_withdrawal"] = (
                                float(numbers[1].replace(",", "")) if len(numbers) > 1 else None
                            )
                        elif line.startswith("จํานวนรายการฝาก"):
                            numbers = re.findall(r"[\d,]+(?:\.\d{2})?", line)
                            record["total_deposit_transaction"] = (
                                float(numbers[0].replace(",", "")) if len(numbers) > 0 else None
                            )
                            record["total_deposit"] = (
                                float(numbers[1].replace(",", "")) if len(numbers) > 1 else None
                            )

                header_records.append(record)

            except Exception as error:
                print(f"⚠️  Skipping page {page_id} due to error: {error}")
                continue

        return header_records

    @staticmethod
    def extract_transactions(pages: List[pdfplumber.page.Page]) -> List[Dict[str, Any]]:
        """
        Extract transaction rows from the table region on each page. 
        We first detect all words in the table crop (config.TABLE_CROP_BOX),
        group them into rows whenever we see a DATE_REGEX match, then parse out
        date, time, description, channel, debit/credit, and balance.
        """
        transaction_records: List[Dict[str, Any]] = []

        for page in pages:
            try:
                page_id = BBLStatementExtractor.extract_page_id(page)

                # Take the crop box defined in config.TABLE_CROP_BOX,
                # but make sure it fits within the page dimensions:
                crop_x0, crop_y0, crop_x1, crop_y1 = config.TABLE_CROP_BOX
                page_width, page_height = page.width, page.height
                safe_crop_box: Tuple[float, float, float, float] = (
                    crop_x0,
                    crop_y0,
                    min(crop_x1, page_width),
                    min(crop_y1, page_height),
                )
                region = page.crop(safe_crop_box)

                # Extract words with a small tolerance so we can cluster them into rows:
                words = region.extract_words(
                    x_tolerance=3, 
                    y_tolerance=3, 
                    use_text_flow=True
                )

                # Find every 'top' coordinate where the text matches a date pattern:
                row_tops = sorted(
                    w["top"] 
                    for w in words 
                    if BBLStatementExtractor._date_regex.match(w["text"])
                )
                print(f"Page {page_id}: found {len(row_tops)} date entries")

                if not row_tops:
                    # No date => no transactions on this page
                    continue

                # Build intervals for each row: each interval spans from row_tops[i] - Y_MARGIN
                # up to row_tops[i+1] - Y_MARGIN (or +15px at the end).
                intervals = [
                    (
                        row_tops[i] - config.Y_MARGIN,
                        row_tops[i + 1] - config.Y_MARGIN 
                        if i + 1 < len(row_tops) 
                        else row_tops[i] + 15,
                    )
                    for i in range(len(row_tops))
                ]

                # Now allocate each word into the correct row index:
                rows: List[List[Dict[str, Any]]] = [[] for _ in intervals]
                for w in words:
                    for idx, (top_min, top_max) in enumerate(intervals):
                        if top_min <= w["top"] < top_max:
                            rows[idx].append(w)
                            break

                # For each row group, parse date, time, description, channel, amounts, etc.
                for idx, row in enumerate(rows):
                    if not row:
                        continue

                    row_text = " ".join(w["text"] for w in row)
                    # If this row matches any FOOTER_KEYS, skip it:
                    if any(key in row_text for key in config.FOOTER_KEYS):
                        continue

                    # Sort words by their vertical (then horizontal) positions:
                    sorted_row = sorted(row, key=lambda w: (w["top"], w["x0"]))

                    # Find the date word in this row
                    date_word = next(
                        (w for w in sorted_row if BBLStatementExtractor._date_regex.match(w["text"])),
                        None,
                    )
                    date_value = (
                        pd.to_datetime(
                            date_word["text"], 
                            format="%d/%m/%y", 
                            dayfirst=True, 
                            errors="coerce"
                        ) 
                        if date_word 
                        else None
                    )

                    # Find a time word on nearly the same 'top' line:
                    time_word = next(
                        (
                            w 
                            for w in sorted_row 
                            if BBLStatementExtractor._time_regex.match(w["text"]) 
                            and abs(w["top"] - (date_word["top"] if date_word else 0)) < 20
                        ),
                        None,
                    )
                    time_value = time_word["text"] if time_word else ""

                    # We will bucket tokens into: description_tokens, channel_via_tokens, withdrawal_tokens, balance_tokens
                    description_tokens: List[str] = []
                    channel_via_tokens: List[str] = []
                    withdrawal_tokens: List[Tuple[str, float]] = []
                    balance_tokens: List[str] = []

                    for w in sorted_row:
                        text, x0, x1 = w["text"], w["x0"], w["x1"]

                        # Skip over actual date/time tokens
                        if BBLStatementExtractor._date_regex.match(text) or BBLStatementExtractor._time_regex.match(text):
                            continue

                        # If it looks like money (e.g. "1,234.56"):
                        if BBLStatementExtractor._money_regex.match(text):
                            # If it falls to the left of the CHANNEL/DC split:
                            if x1 <= config.X_SPLIT_CHANNEL_DC + config.X_TOLERANCE:
                                withdrawal_tokens.append((text, x1))
                            else:
                                balance_tokens.append(text)
                            continue

                        # If x0 is very far left, treat it as description
                        if x0 <= config.X_SPLIT_CODE_CHANNEL + config.X_TOLERANCE:
                            description_tokens.append(text)
                        # If x0 is far right, treat it as channel/via
                        elif x0 >= config.X_SPLIT_CHANNEL_VIA - config.X_TOLERANCE:
                            channel_via_tokens.append(text)
                        else:
                            description_tokens.append(text)

                    channel_value = " ".join(channel_via_tokens).strip()

                    withdrawal_amount = None
                    deposit_amount = None
                    # Among all withdrawal_tokens, decide which one is 'withdrawal' vs 'deposit'
                    for value_str, x1 in withdrawal_tokens:
                        value = float(value_str.replace(",", ""))
                        if x1 <= config.X_SPLIT_WITHDRAW_DEP + config.X_TOLERANCE:
                            withdrawal_amount = value
                        else:
                            deposit_amount = value

                    balance_amount = (
                        float(balance_tokens[-1].replace(",", "")) 
                        if balance_tokens 
                        else None
                    )

                    transaction_records.append({
                        "page_id": page_id,
                        "date": date_value,
                        "time": time_value,
                        "description": "",
                        "channel": channel_value,
                        "withdrawal": withdrawal_amount,
                        "deposit": deposit_amount,
                        "balance": balance_amount,
                        "transaction_type": " ".join(description_tokens).strip(),
                    })

                print(f"Page {page_id}: extracted {len(transaction_records)} transactions so far")

            except Exception as error:
                print(f"⚠️ Skipping transactions on page {getattr(page, 'page_number', '?')}: {error}")
                continue

        return transaction_records

    @staticmethod
    def clean_all_floats(
        header_dataframe: pd.DataFrame,
        transaction_dataframe: pd.DataFrame,
    ) -> None:
        """
        Clean and convert all numeric text columns to floats in both DataFrames.
        This mutates header_dataframe and transaction_dataframe in-place.
        """
        float_columns_transactions = ["withdrawal", "deposit", "balance"]
        for column in float_columns_transactions:
            if column in transaction_dataframe.columns:
                transaction_dataframe[column] = (
                    transaction_dataframe[column]
                    .astype(str)
                    .str.replace(r"[^\d.]", "", regex=True)
                    .replace({"": np.nan, "NA": np.nan})
                    .astype(float)
                )

        float_columns_headers = [
            "total_withdrawal_transaction",
            "total_withdrawal",
            "total_deposit_transaction",
            "total_deposit",
        ]
        for column in float_columns_headers:
            if column in header_dataframe.columns:
                header_dataframe[column] = (
                    header_dataframe[column]
                    .astype(str)
                    .str.replace(r"[^\d.]", "", regex=True)
                    .replace({"": np.nan, "NA": np.nan})
                    .astype(float)
                )

    @staticmethod
    def build_and_clean_dataframes(
        header_records: List[Dict[str, Any]],
        transaction_records: List[Dict[str, Any]],
    ) -> Tuple[pd.DataFrame, pd.DataFrame]:
        """
        1. Build DataFrames from raw header_records and transaction_records.
        2. Drop blank or malformed page_ids.
        3. Rename columns so 'withdrawal'→'debit', 'deposit'→'credit', etc.
        4. Reorder columns, then clean numeric fields via clean_all_floats().
        """
        header_dataframe = pd.DataFrame(header_records)
        transaction_dataframe = pd.DataFrame(transaction_records)

        # Drop any header rows where page_id is blank or whitespace
        header_dataframe = header_dataframe[
            header_dataframe["page_id"].str.strip() != ""
        ].copy()

        # Ensure an 'address' column always exists (some statements may or may not have it)
        header_dataframe["address"] = ""

        # Rename total fields
        header_dataframe = header_dataframe.rename(
            columns={
                "total_withdrawal": "total_debit",
                "total_deposit": "total_credit",
                "total_withdrawal_transaction": "total_debit_transaction",
                "total_deposit_transaction": "total_credit_transaction",
            }
        ).reset_index(drop=True)

        # Filter out any page_ids that don't start with a digit (malformed)
        header_dataframe = header_dataframe[
            header_dataframe["page_id"].str.match(r"^\d", na=False)
        ].copy()

        # Keep only rows in transaction_dataframe that have either a withdrawal or deposit
        transaction_dataframe = transaction_dataframe[
            (~transaction_dataframe["withdrawal"].isnull())
            | (~transaction_dataframe["deposit"].isnull())
        ].copy()

        # Rename columns to standard names:
        transaction_dataframe = transaction_dataframe.rename(
            columns={"withdrawal": "debit", "deposit": "credit"}
        )

        # Reorder columns into a fixed schema
        transaction_dataframe = transaction_dataframe[
            [
                "page_id",
                "date",
                "time",
                "description",
                "channel",
                "debit",
                "credit",
                "balance",
                "transaction_type",
            ]
        ].copy()

        # Finally, clean all the numeric columns in both DataFrames
        BBLStatementExtractor.clean_all_floats(header_dataframe, transaction_dataframe)

        return header_dataframe, transaction_dataframe

    @staticmethod
    def run(
        pdf_path: str,
        password: Optional[str] = None,
    ) -> Tuple[pd.DataFrame, pd.DataFrame]:
        """
        Execute extraction and return cleaned DataFrames.
        This is the only method that requires you to pass in the PDF path and password.
        """
        with pdfplumber.open(pdf_path, password=password) as pdf:
            pages = pdf.pages
            header_list = BBLStatementExtractor.extract_headers(pages)
            transaction_list = BBLStatementExtractor.extract_transactions(pages)

        return BBLStatementExtractor.build_and_clean_dataframes(
            header_list, transaction_list
        )


# Example usage:
# ---------------------------------------------
# from extractor import BBLStatementExtractor
#
# pdf_file = "/path/to/your/BBL_statement.pdf"
# pwd = "your_optional_password"
# headers_df, transactions_df = BBLStatementExtractor.run(pdf_file, pwd)
#
# print(f"Total headers extracted: {len(headers_df)}")
# print(tabulate(headers_df, headers='keys', tablefmt='psql', showindex=False))
# print(f"Total transactions extracted: {len(transactions_df)}")
# print(tabulate(transactions_df, headers='keys', tablefmt='psql', showindex=False))

# %%
headers_df
# Out:
#   page_id         account_name account_number                   period  \
# 0     1/2  น.ส. มัณฑนา ปณะจิตร  093-7-33805-1  01/05/2023 - 18/08/2023
# 1     2/2  น.ส. มัณฑนา ปณะจิตร  093-7-33805-1  01/05/2023 - 18/08/2023
#
#    total_debit_transaction  total_debit  total_credit_transaction  \
# 0                      NaN          NaN                       NaN
# 1                     44.0      62325.0                      23.0
#
#    total_credit address
# 0           NaN
# 1      62324.83

# %%
transactions_df
# Out:
#    page_id       date time description channel   debit   credit  balance  \
# 1      1/2 2023-05-12                     Auto     NaN  9625.54  9626.23
# 2      1/2 2023-05-12                   mPhone  9626.0      NaN     0.23
# 3      1/2 2023-05-19                   mPhone     NaN  5000.00  5000.23
# 4      1/2 2023-05-19                   mPhone  5000.0      NaN     0.23
# 5      1/2 2023-05-24                   mPhone     NaN   500.00   500.23
# ..     ...        ...  ...         ...     ...     ...      ...      ...
# 63     2/2 2023-08-11                   mPhone  1000.0      NaN  4679.52
# 64     2/2 2023-08-11                   mPhone     NaN  1000.00  5679.52
# 65     2/2 2023-08-12                   mPhone   179.0      NaN  5500.52
# 66     2/2 2023-08-12                   mPhone   200.0      NaN  5300.52
# 67     2/2 2023-08-12                   mPhone  5300.0      NaN     0.52
#
#    transaction_type
# 1            SALARY
# 2    TRF. PROMPTPAY
# 3     TRF FR OTH BK
# 4     TRF TO OTH BK
# 5     TRF FR OTH BK
# ..              ...
# 63   TRF. PROMPTPAY
# 64    TRF FR OTH BK
# 65   TRF. PROMPTPAY
# 66   TRF. PROMPTPAY
# 67    TRF TO OTH BK
#
# [67 rows x 9 columns]

# %%
#!/usr/bin/env python3
import os, traceback
import numpy as np
import pandas as pd
from typing import Tuple, List, Dict, Any, Optional
import pdfplumber
from bbl_extractor import BBLStatementExtractor

# — your existing imports & extraction functions here —
# from your_module import extract_header, extract_transactions

INPUT_FOLDER = "/Users/if658228/Downloads/OneDrive_1_5-20-2025/agentic_extraction/Dataset04/BBL"
PASSWORD: Optional[str] = None

def process_folder(input_folder: str) -> Tuple[pd.DataFrame, pd.DataFrame, List[dict]]:
    tx_list, hdr_list, failures = [], [], []
    for fn in os.listdir(input_folder):
        if not fn.lower().endswith(".pdf"):
            continue
        path = os.path.join(input_folder, fn)
        try:
            with pdfplumber.open(path, password=PASSWORD) as pdf:
                pages = pdf.pages
                df_hdr, df_tx = BBLStatementExtractor().run(path,None)
            df_hdr["source_file"] = fn
            df_tx ["source_file"] = fn
            
            tx_list.append(df_tx)
            hdr_list.append(df_hdr)
        except Exception as e:
            failures.append({
                "file": fn,
                "error": str(e),
                "traceback": traceback.format_exc()
            })
    all_tx  = pd.concat(tx_list, ignore_index=True) if tx_list else pd.DataFrame()
    all_hdr = pd.concat(hdr_list, ignore_index=True) if hdr_list else pd.DataFrame()
    return all_tx, all_hdr, failures

def validate_bbl(df_tx_all: pd.DataFrame, df_hdr_all: pd.DataFrame) -> pd.DataFrame:
    # STEP 1: ensure numeric
    tx_clean = df_tx_all.copy()
    tx_clean[['debit','credit']] = (
        tx_clean[['debit','credit']]
        .replace('', np.nan)
        .astype(float)
    )

    # STEP 2: sums per file
    sums = (tx_clean
            .groupby('source_file')[['debit','credit']]
            .sum(min_count=1)
            .rename(columns={
                'debit':'sum_debit',
                'credit'   :'sum_credit'
            }))

    # STEP 3: counts per file
    counts = (tx_clean
              .groupby('source_file')[['debit','credit']]
              .count()
              .rename(columns={
                  'debit':'count_debit_tx',
                  'credit'   :'count_credit_tx'
              }))

    # STEP 4: pick header summary columns (drop pages without both)
    # note: we sum the two *_transaction fields into total_txns
    hdr = (df_hdr_all
           .dropna(subset=['total_debit_transaction','total_credit_transaction'])
           .groupby('source_file')
           .agg({
               'total_debit_transaction':'sum',
               'total_debit'            :'sum',
               'total_credit_transaction'   :'sum',
               'total_credit'               :'sum'
           })
          )
    hdr = hdr.rename(columns={
        'total_debit_transaction':'total_debit_txns',
        'total_debit'            :'total_debit',
        'total_credit_transaction'   :'total_credit_txns',
        'total_credit'               :'total_credit'
    })


    # STEP 5: merge & compare
    cmp = (hdr
           .join(sums,   how='left')
           .join(counts, how='left')
           .reset_index()
           .rename(columns={'source_file':'file'}))

    summary = cmp.assign(
        debit_amount_match = lambda d: np.isclose(d['total_debit'], d['sum_debit'], atol=1e-2),
        credit_amount_match    = lambda d: np.isclose(d['total_credit'],    d['sum_credit'],    atol=1e-2),
        transaction_count_debit_match = lambda d: d['total_debit_txns'] == (d['count_debit_tx']),
        transaction_count_credit_match = lambda d: d['total_credit_txns'] == (d['count_credit_tx'])
        
    )[
        ['file',
         'total_debit','sum_debit','debit_amount_match',
         'total_credit',   'sum_credit',   'credit_amount_match',
         'total_credit_txns','total_debit_txns', 'count_debit_tx','count_credit_tx','transaction_count_debit_match','transaction_count_credit_match']
    ]

    return summary

if __name__ == "__main__":
    df_tx_all, df_hdr_all, failures = process_folder(INPUT_FOLDER)
    print(f"Processed transactions: {df_tx_all.shape}, headers: {df_hdr_all.shape}")
    if failures:
        print(f"\n⚠️ {len(failures)} failures; inspect `failures` list.")
    if df_tx_all.empty or df_hdr_all.empty:
        print("No data to validate; exiting.")
        exit(1)
    print(df_tx_all,df_hdr_all)
    summary = validate_bbl(df_tx_all, df_hdr_all)
    print("\n--- Validation Summary per File ---")
    print(summary.to_string(index=False))

    bad = summary.loc[~(summary.debit_amount_match
                        & summary.credit_amount_match
                        & summary.transaction_count_debit_match
                        & summary.transaction_count_credit_match)]
    if not bad.empty:
        bad = bad.assign(
            diff_debit = bad['sum_debit'] - bad['total_debit'],
            diff_credit    = bad['sum_credit']    - bad['total_credit']
        )
        print("\n❌ Files with mismatches:")
        print(bad.to_string(index=False))
    else:
        print("\n✅ All files validated successfully!")
# Out:
# Page 1/5: found 36 date entries
# Page 1/5: extracted 36 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 72 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 108 transactions so far
# Page 4/5: found 36 date entries
# Page 4/5: extracted 144 transactions so far
# Page 5/5: found 2 date entries
# Page 5/5: extracted 146 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 7 date entries
# Page 2/2: extracted 43 transactions so far
# Page 1/1: found 18 date entries
# Page 1/1: extracted 18 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 7 date entries
# Page 3/3: extracted 79 transactions so far
# Page 1/9: found 36 date entries
# Page 1/9: extracted 36 transactions so far
# Page 2/9: found 36 date entries
# Page 2/9: extracted 72 transactions so far
# Page 3/9: found 36 date entries
# Page 3/9: extracted 108 transactions so far
# Page 4/9: found 36 date entries
# Page 4/9: extracted 144 transactions so far
# Page 5/9: found 36 date entries
# Page 5/9: extracted 180 transactions so far
# Page 6/9: found 36 date entries
# Page 6/9: extracted 216 transactions so far
# Page 7/9: found 36 date entries
# Page 7/9: extracted 252 transactions so far
# Page 8/9: found 36 date entries
# Page 8/9: extracted 288 transactions so far
# Page 9/9: found 3 date entries
# Page 9/9: extracted 291 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 1 date entries
# Page 2/2: extracted 37 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 35 date entries
# Page 3/4: extracted 107 transactions so far
# Page 4/4: found 1 date entries
# Page 4/4: extracted 108 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 14 date entries
# Page 2/2: extracted 50 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 86 transactions so far
# Page 2/2: found 14 date entries
# Page 2/2: extracted 100 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 1 date entries
# Page 6/6: extracted 181 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 32 date entries
# Page 3/3: extracted 104 transactions so far
# Page 1/8: found 36 date entries
# Page 1/8: extracted 36 transactions so far
# Page 2/8: found 36 date entries
# Page 2/8: extracted 72 transactions so far
# Page 3/8: found 36 date entries
# Page 3/8: extracted 108 transactions so far
# Page 4/8: found 36 date entries
# Page 4/8: extracted 144 transactions so far
# Page 5/8: found 36 date entries
# Page 5/8: extracted 180 transactions so far
# Page 6/8: found 36 date entries
# Page 6/8: extracted 216 transactions so far
# Page 7/8: found 36 date entries
# Page 7/8: extracted 252 transactions so far
# Page 8/8: found 17 date entries
# Page 8/8: extracted 269 transactions so far
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page 1/10: found 36 date entries
# Page 1/10: extracted 36 transactions so far
# Page 2/10: found 36 date entries
# Page 2/10: extracted 72 transactions so far
# Page 3/10: found 36 date entries
# Page 3/10: extracted 108 transactions so far
# Page 4/10: found 36 date entries
# Page 4/10: extracted 144 transactions so far
# Page 5/10: found 36 date entries
# Page 5/10: extracted 180 transactions so far
# Page 6/10: found 36 date entries
# Page 6/10: extracted 216 transactions so far
# Page 7/10: found 36 date entries
# Page 7/10: extracted 252 transactions so far
# Page 8/10: found 36 date entries
# Page 8/10: extracted 288 transactions so far
# Page 9/10: found 36 date entries
# Page 9/10: extracted 324 transactions so far
# Page 10/10: found 21 date entries
# Page 10/10: extracted 345 transactions so far
# Page : found 0 date entries
# Page 1/10: found 36 date entries
# Page 1/10: extracted 381 transactions so far
# Page 2/10: found 36 date entries
# Page 2/10: extracted 417 transactions so far
# Page 3/10: found 36 date entries
# Page 3/10: extracted 453 transactions so far
# Page 4/10: found 36 date entries
# Page 4/10: extracted 489 transactions so far
# Page 5/10: found 36 date entries
# Page 5/10: extracted 525 transactions so far
# Page 6/10: found 36 date entries
# Page 6/10: extracted 561 transactions so far
# Page 7/10: found 36 date entries
# Page 7/10: extracted 597 transactions so far
# Page 8/10: found 36 date entries
# Page 8/10: extracted 633 transactions so far
# Page 9/10: found 36 date entries
# Page 9/10: extracted 669 transactions so far
# Page 10/10: found 21 date entries
# Page 10/10: extracted 690 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 27 date entries
# Page 4/4: extracted 135 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 27 date entries
# Page 6/6: extracted 207 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 1 date entries
# Page 3/3: extracted 73 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 109 transactions so far
# Page 2/2: found 32 date entries
# Page 2/2: extracted 141 transactions so far
# Page 1/9: found 36 date entries
# Page 1/9: extracted 36 transactions so far
# Page 2/9: found 36 date entries
# Page 2/9: extracted 72 transactions so far
# Page 3/9: found 36 date entries
# Page 3/9: extracted 108 transactions so far
# Page 4/9: found 36 date entries
# Page 4/9: extracted 144 transactions so far
# Page 5/9: found 36 date entries
# Page 5/9: extracted 180 transactions so far
# Page 6/9: found 36 date entries
# Page 6/9: extracted 216 transactions so far
# Page 7/9: found 36 date entries
# Page 7/9: extracted 252 transactions so far
# Page 8/9: found 36 date entries
# Page 8/9: extracted 288 transactions so far
# Page 9/9: found 5 date entries
# Page 9/9: extracted 293 transactions so far
# Page 1/9: found 36 date entries
# Page 1/9: extracted 36 transactions so far
# Page 2/9: found 36 date entries
# Page 2/9: extracted 72 transactions so far
# Page 3/9: found 36 date entries
# Page 3/9: extracted 108 transactions so far
# Page 4/9: found 36 date entries
# Page 4/9: extracted 144 transactions so far
# Page 5/9: found 36 date entries
# Page 5/9: extracted 180 transactions so far
# Page 6/9: found 36 date entries
# Page 6/9: extracted 216 transactions so far
# Page 7/9: found 36 date entries
# Page 7/9: extracted 252 transactions so far
# Page 8/9: found 36 date entries
# Page 8/9: extracted 288 transactions so far
# Page 9/9: found 18 date entries
# Page 9/9: extracted 306 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 35 date entries
# Page 3/4: extracted 107 transactions so far
# Page 4/4: found 1 date entries
# Page 4/4: extracted 108 transactions so far
# Page 1/12: found 36 date entries
# Page 1/12: extracted 36 transactions so far
# Page 2/12: found 36 date entries
# Page 2/12: extracted 72 transactions so far
# Page 3/12: found 36 date entries
# Page 3/12: extracted 108 transactions so far
# Page 4/12: found 36 date entries
# Page 4/12: extracted 144 transactions so far
# Page 5/12: found 36 date entries
# Page 5/12: extracted 180 transactions so far
# Page 6/12: found 36 date entries
# Page 6/12: extracted 216 transactions so far
# Page 7/12: found 36 date entries
# Page 7/12: extracted 252 transactions so far
# Page 8/12: found 36 date entries
# Page 8/12: extracted 288 transactions so far
# Page 9/12: found 36 date entries
# Page 9/12: extracted 324 transactions so far
# Page 10/12: found 36 date entries
# Page 10/12: extracted 360 transactions so far
# Page 11/12: found 36 date entries
# Page 11/12: extracted 396 transactions so far
# Page 12/12: found 3 date entries
# Page 12/12: extracted 399 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 28 date entries
# Page 6/6: extracted 208 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 11 date entries
# Page 6/6: extracted 191 transactions so far
# Page 1/5: found 36 date entries
# Page 1/5: extracted 36 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 72 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 108 transactions so far
# Page 4/5: found 36 date entries
# Page 4/5: extracted 144 transactions so far
# Page 5/5: found 6 date entries
# Page 5/5: extracted 150 transactions so far
# Page 1/19: found 36 date entries
# Page 1/19: extracted 36 transactions so far
# Page 2/19: found 36 date entries
# Page 2/19: extracted 72 transactions so far
# Page 3/19: found 36 date entries
# Page 3/19: extracted 108 transactions so far
# Page 4/19: found 36 date entries
# Page 4/19: extracted 144 transactions so far
# Page 5/19: found 36 date entries
# Page 5/19: extracted 180 transactions so far
# Page 6/19: found 36 date entries
# Page 6/19: extracted 216 transactions so far
# Page 7/19: found 36 date entries
# Page 7/19: extracted 252 transactions so far
# Page 8/19: found 36 date entries
# Page 8/19: extracted 288 transactions so far
# Page 9/19: found 36 date entries
# Page 9/19: extracted 324 transactions so far
# Page 10/19: found 36 date entries
# Page 10/19: extracted 360 transactions so far
# Page 11/19: found 36 date entries
# Page 11/19: extracted 396 transactions so far
# Page 12/19: found 36 date entries
# Page 12/19: extracted 432 transactions so far
# Page 13/19: found 36 date entries
# Page 13/19: extracted 468 transactions so far
# Page 14/19: found 36 date entries
# Page 14/19: extracted 504 transactions so far
# Page 15/19: found 36 date entries
# Page 15/19: extracted 540 transactions so far
# Page 16/19: found 36 date entries
# Page 16/19: extracted 576 transactions so far
# Page 17/19: found 36 date entries
# Page 17/19: extracted 612 transactions so far
# Page 18/19: found 36 date entries
# Page 18/19: extracted 648 transactions so far
# Page 19/19: found 6 date entries
# Page 19/19: extracted 654 transactions so far
# Page 1/31: found 36 date entries
# Page 1/31: extracted 36 transactions so far
# Page 2/31: found 36 date entries
# Page 2/31: extracted 72 transactions so far
# Page 3/31: found 36 date entries
# Page 3/31: extracted 108 transactions so far
# Page 4/31: found 36 date entries
# Page 4/31: extracted 144 transactions so far
# Page 5/31: found 36 date entries
# Page 5/31: extracted 180 transactions so far
# Page 6/31: found 36 date entries
# Page 6/31: extracted 216 transactions so far
# Page 7/31: found 36 date entries
# Page 7/31: extracted 252 transactions so far
# Page 8/31: found 36 date entries
# Page 8/31: extracted 288 transactions so far
# Page 9/31: found 36 date entries
# Page 9/31: extracted 324 transactions so far
# Page 10/31: found 36 date entries
# Page 10/31: extracted 360 transactions so far
# Page 11/31: found 36 date entries
# Page 11/31: extracted 396 transactions so far
# Page 12/31: found 36 date entries
# Page 12/31: extracted 432 transactions so far
# Page 13/31: found 36 date entries
# Page 13/31: extracted 468 transactions so far
# Page 14/31: found 36 date entries
# Page 14/31: extracted 504 transactions so far
# Page 15/31: found 36 date entries
# Page 15/31: extracted 540 transactions so far
# Page 16/31: found 36 date entries
# Page 16/31: extracted 576 transactions so far
# Page 17/31: found 36 date entries
# Page 17/31: extracted 612 transactions so far
# Page 18/31: found 36 date entries
# Page 18/31: extracted 648 transactions so far
# Page 19/31: found 36 date entries
# Page 19/31: extracted 684 transactions so far
# Page 20/31: found 36 date entries
# Page 20/31: extracted 720 transactions so far
# Page 21/31: found 36 date entries
# Page 21/31: extracted 756 transactions so far
# Page 22/31: found 36 date entries
# Page 22/31: extracted 792 transactions so far
# Page 23/31: found 36 date entries
# Page 23/31: extracted 828 transactions so far
# Page 24/31: found 36 date entries
# Page 24/31: extracted 864 transactions so far
# Page 25/31: found 36 date entries
# Page 25/31: extracted 900 transactions so far
# Page 26/31: found 36 date entries
# Page 26/31: extracted 936 transactions so far
# Page 27/31: found 36 date entries
# Page 27/31: extracted 972 transactions so far
# Page 28/31: found 36 date entries
# Page 28/31: extracted 1008 transactions so far
# Page 29/31: found 36 date entries
# Page 29/31: extracted 1044 transactions so far
# Page 30/31: found 36 date entries
# Page 30/31: extracted 1080 transactions so far
# Page 31/31: found 16 date entries
# Page 31/31: extracted 1096 transactions so far
# Page 1/12: found 36 date entries
# Page 1/12: extracted 36 transactions so far
# Page 2/12: found 36 date entries
# Page 2/12: extracted 72 transactions so far
# Page 3/12: found 36 date entries
# Page 3/12: extracted 108 transactions so far
# Page 4/12: found 36 date entries
# Page 4/12: extracted 144 transactions so far
# Page 5/12: found 36 date entries
# Page 5/12: extracted 180 transactions so far
# Page 6/12: found 36 date entries
# Page 6/12: extracted 216 transactions so far
# Page 7/12: found 36 date entries
# Page 7/12: extracted 252 transactions so far
# Page 8/12: found 36 date entries
# Page 8/12: extracted 288 transactions so far
# Page 9/12: found 36 date entries
# Page 9/12: extracted 324 transactions so far
# Page 10/12: found 36 date entries
# Page 10/12: extracted 360 transactions so far
# Page 11/12: found 36 date entries
# Page 11/12: extracted 396 transactions so far
# Page 12/12: found 4 date entries
# Page 12/12: extracted 400 transactions so far
# Page 1/1: found 10 date entries
# Page 1/1: extracted 10 transactions so far
# Page 1/20: found 36 date entries
# Page 1/20: extracted 36 transactions so far
# Page 2/20: found 36 date entries
# Page 2/20: extracted 72 transactions so far
# Page 3/20: found 36 date entries
# Page 3/20: extracted 108 transactions so far
# Page 4/20: found 36 date entries
# Page 4/20: extracted 144 transactions so far
# Page 5/20: found 36 date entries
# Page 5/20: extracted 180 transactions so far
# Page 6/20: found 36 date entries
# Page 6/20: extracted 216 transactions so far
# Page 7/20: found 36 date entries
# Page 7/20: extracted 252 transactions so far
# Page 8/20: found 36 date entries
# Page 8/20: extracted 288 transactions so far
# Page 9/20: found 36 date entries
# Page 9/20: extracted 324 transactions so far
# Page 10/20: found 36 date entries
# Page 10/20: extracted 360 transactions so far
# Page 11/20: found 36 date entries
# Page 11/20: extracted 396 transactions so far
# Page 12/20: found 36 date entries
# Page 12/20: extracted 432 transactions so far
# Page 13/20: found 36 date entries
# Page 13/20: extracted 468 transactions so far
# Page 14/20: found 36 date entries
# Page 14/20: extracted 504 transactions so far
# Page 15/20: found 36 date entries
# Page 15/20: extracted 540 transactions so far
# Page 16/20: found 36 date entries
# Page 16/20: extracted 576 transactions so far
# Page 17/20: found 36 date entries
# Page 17/20: extracted 612 transactions so far
# Page 18/20: found 36 date entries
# Page 18/20: extracted 648 transactions so far
# Page 19/20: found 36 date entries
# Page 19/20: extracted 684 transactions so far
# Page 20/20: found 22 date entries
# Page 20/20: extracted 706 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 8 date entries
# Page 2/2: extracted 44 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 13 date entries
# Page 6/6: extracted 193 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 22 date entries
# Page 6/6: extracted 202 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 26 date entries
# Page 3/3: extracted 98 transactions so far
# Page 1/13: found 36 date entries
# Page 1/13: extracted 36 transactions so far
# Page 2/13: found 36 date entries
# Page 2/13: extracted 72 transactions so far
# Page 3/13: found 36 date entries
# Page 3/13: extracted 108 transactions so far
# Page 4/13: found 36 date entries
# Page 4/13: extracted 144 transactions so far
# Page 5/13: found 36 date entries
# Page 5/13: extracted 180 transactions so far
# Page 6/13: found 36 date entries
# Page 6/13: extracted 216 transactions so far
# Page 7/13: found 36 date entries
# Page 7/13: extracted 252 transactions so far
# Page 8/13: found 36 date entries
# Page 8/13: extracted 288 transactions so far
# Page 9/13: found 36 date entries
# Page 9/13: extracted 324 transactions so far
# Page 10/13: found 36 date entries
# Page 10/13: extracted 360 transactions so far
# Page 11/13: found 36 date entries
# Page 11/13: extracted 396 transactions so far
# Page 12/13: found 36 date entries
# Page 12/13: extracted 432 transactions so far
# Page 13/13: found 30 date entries
# Page 13/13: extracted 462 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 17 date entries
# Page 2/2: extracted 53 transactions so far
# Page : found 0 date entries
# Page 1/24: found 36 date entries
# Page 1/24: extracted 36 transactions so far
# Page 2/24: found 36 date entries
# Page 2/24: extracted 72 transactions so far
# Page 3/24: found 36 date entries
# Page 3/24: extracted 108 transactions so far
# Page 4/24: found 36 date entries
# Page 4/24: extracted 144 transactions so far
# Page 5/24: found 36 date entries
# Page 5/24: extracted 180 transactions so far
# Page 6/24: found 36 date entries
# Page 6/24: extracted 216 transactions so far
# Page 7/24: found 36 date entries
# Page 7/24: extracted 252 transactions so far
# Page 8/24: found 36 date entries
# Page 8/24: extracted 288 transactions so far
# Page 9/24: found 36 date entries
# Page 9/24: extracted 324 transactions so far
# Page 10/24: found 36 date entries
# Page 10/24: extracted 360 transactions so far
# Page 11/24: found 36 date entries
# Page 11/24: extracted 396 transactions so far
# Page 12/24: found 36 date entries
# Page 12/24: extracted 432 transactions so far
# Page 13/24: found 36 date entries
# Page 13/24: extracted 468 transactions so far
# Page 14/24: found 36 date entries
# Page 14/24: extracted 504 transactions so far
# Page 15/24: found 36 date entries
# Page 15/24: extracted 540 transactions so far
# Page 16/24: found 36 date entries
# Page 16/24: extracted 576 transactions so far
# Page 17/24: found 36 date entries
# Page 17/24: extracted 612 transactions so far
# Page 18/24: found 36 date entries
# Page 18/24: extracted 648 transactions so far
# Page 19/24: found 36 date entries
# Page 19/24: extracted 684 transactions so far
# Page 20/24: found 36 date entries
# Page 20/24: extracted 720 transactions so far
# Page 21/24: found 36 date entries
# Page 21/24: extracted 756 transactions so far
# Page 22/24: found 36 date entries
# Page 22/24: extracted 792 transactions so far
# Page 23/24: found 36 date entries
# Page 23/24: extracted 828 transactions so far
# Page 24/24: found 15 date entries
# Page 24/24: extracted 843 transactions so far
# Page 1/1: found 20 date entries
# Page 1/1: extracted 20 transactions so far
# Page 1/5: found 36 date entries
# Page 1/5: extracted 36 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 72 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 108 transactions so far
# Page 4/5: found 36 date entries
# Page 4/5: extracted 144 transactions so far
# Page 5/5: found 15 date entries
# Page 5/5: extracted 159 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 28 date entries
# Page 3/3: extracted 100 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 136 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 172 transactions so far
# Page 3/3: found 8 date entries
# Page 3/3: extracted 180 transactions so far
# Page 1/13: found 36 date entries
# Page 1/13: extracted 36 transactions so far
# Page 2/13: found 36 date entries
# Page 2/13: extracted 72 transactions so far
# Page 3/13: found 36 date entries
# Page 3/13: extracted 108 transactions so far
# Page 4/13: found 36 date entries
# Page 4/13: extracted 144 transactions so far
# Page 5/13: found 36 date entries
# Page 5/13: extracted 180 transactions so far
# Page 6/13: found 36 date entries
# Page 6/13: extracted 216 transactions so far
# Page 7/13: found 36 date entries
# Page 7/13: extracted 252 transactions so far
# Page 8/13: found 36 date entries
# Page 8/13: extracted 288 transactions so far
# Page 9/13: found 36 date entries
# Page 9/13: extracted 324 transactions so far
# Page 10/13: found 36 date entries
# Page 10/13: extracted 360 transactions so far
# Page 11/13: found 36 date entries
# Page 11/13: extracted 396 transactions so far
# Page 12/13: found 36 date entries
# Page 12/13: extracted 432 transactions so far
# Page 13/13: found 3 date entries
# Page 13/13: extracted 435 transactions so far
# Page 1/10: found 36 date entries
# Page 1/10: extracted 36 transactions so far
# Page 2/10: found 36 date entries
# Page 2/10: extracted 72 transactions so far
# Page 3/10: found 36 date entries
# Page 3/10: extracted 108 transactions so far
# Page 4/10: found 36 date entries
# Page 4/10: extracted 144 transactions so far
# Page 5/10: found 36 date entries
# Page 5/10: extracted 180 transactions so far
# Page 6/10: found 36 date entries
# Page 6/10: extracted 216 transactions so far
# Page 7/10: found 36 date entries
# Page 7/10: extracted 252 transactions so far
# Page 8/10: found 36 date entries
# Page 8/10: extracted 288 transactions so far
# Page 9/10: found 36 date entries
# Page 9/10: extracted 324 transactions so far
# Page 10/10: found 1 date entries
# Page 10/10: extracted 325 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 32 date entries
# Page 4/4: extracted 140 transactions so far
# Page 1/1: found 18 date entries
# Page 1/1: extracted 18 transactions so far
# Page 1/8: found 36 date entries
# Page 1/8: extracted 36 transactions so far
# Page 2/8: found 36 date entries
# Page 2/8: extracted 72 transactions so far
# Page 3/8: found 36 date entries
# Page 3/8: extracted 108 transactions so far
# Page 4/8: found 36 date entries
# Page 4/8: extracted 144 transactions so far
# Page 5/8: found 36 date entries
# Page 5/8: extracted 180 transactions so far
# Page 6/8: found 36 date entries
# Page 6/8: extracted 216 transactions so far
# Page 7/8: found 36 date entries
# Page 7/8: extracted 252 transactions so far
# Page 8/8: found 11 date entries
# Page 8/8: extracted 263 transactions so far
# Page 1/13: found 36 date entries
# Page 1/13: extracted 36 transactions so far
# Page 2/13: found 36 date entries
# Page 2/13: extracted 72 transactions so far
# Page 3/13: found 36 date entries
# Page 3/13: extracted 108 transactions so far
# Page 4/13: found 36 date entries
# Page 4/13: extracted 144 transactions so far
# Page 5/13: found 36 date entries
# Page 5/13: extracted 180 transactions so far
# Page 6/13: found 36 date entries
# Page 6/13: extracted 216 transactions so far
# Page 7/13: found 36 date entries
# Page 7/13: extracted 252 transactions so far
# Page 8/13: found 36 date entries
# Page 8/13: extracted 288 transactions so far
# Page 9/13: found 36 date entries
# Page 9/13: extracted 324 transactions so far
# Page 10/13: found 36 date entries
# Page 10/13: extracted 360 transactions so far
# Page 11/13: found 36 date entries
# Page 11/13: extracted 396 transactions so far
# Page 12/13: found 36 date entries
# Page 12/13: extracted 432 transactions so far
# Page 13/13: found 19 date entries
# Page 13/13: extracted 451 transactions so far
# Page 1/7: found 36 date entries
# Page 1/7: extracted 487 transactions so far
# Page 2/7: found 36 date entries
# Page 2/7: extracted 523 transactions so far
# Page 3/7: found 36 date entries
# Page 3/7: extracted 559 transactions so far
# Page 4/7: found 36 date entries
# Page 4/7: extracted 595 transactions so far
# Page 5/7: found 36 date entries
# Page 5/7: extracted 631 transactions so far
# Page 6/7: found 36 date entries
# Page 6/7: extracted 667 transactions so far
# Page 7/7: found 7 date entries
# Page 7/7: extracted 674 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 19 date entries
# Page 4/4: extracted 127 transactions so far
# Page 1/1: found 16 date entries
# Page 1/1: extracted 16 transactions so far
# Page 1/7: found 36 date entries
# Page 1/7: extracted 36 transactions so far
# Page 2/7: found 36 date entries
# Page 2/7: extracted 72 transactions so far
# Page 3/7: found 36 date entries
# Page 3/7: extracted 108 transactions so far
# Page 4/7: found 36 date entries
# Page 4/7: extracted 144 transactions so far
# Page 5/7: found 36 date entries
# Page 5/7: extracted 180 transactions so far
# Page 6/7: found 36 date entries
# Page 6/7: extracted 216 transactions so far
# Page 7/7: found 4 date entries
# Page 7/7: extracted 220 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 24 date entries
# Page 2/2: extracted 60 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 9 date entries
# Page 2/2: extracted 45 transactions so far
# Page : found 0 date entries
# Page : found 0 date entries
# Page 1/2: found 36 date entries
# Page 1/2: extracted 81 transactions so far
# Page 2/2: found 9 date entries
# Page 2/2: extracted 90 transactions so far
# Page : found 0 date entries
# Page : found 0 date entries
# Page 1/10: found 36 date entries
# Page 1/10: extracted 36 transactions so far
# Page 2/10: found 36 date entries
# Page 2/10: extracted 72 transactions so far
# Page 3/10: found 36 date entries
# Page 3/10: extracted 108 transactions so far
# Page 4/10: found 36 date entries
# Page 4/10: extracted 144 transactions so far
# Page 5/10: found 36 date entries
# Page 5/10: extracted 180 transactions so far
# Page 6/10: found 36 date entries
# Page 6/10: extracted 216 transactions so far
# Page 7/10: found 36 date entries
# Page 7/10: extracted 252 transactions so far
# Page 8/10: found 36 date entries
# Page 8/10: extracted 288 transactions so far
# Page 9/10: found 34 date entries
# Page 9/10: extracted 322 transactions so far
# Page 10/10: found 1 date entries
# Page 10/10: extracted 323 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 22 date entries
# Page 4/4: extracted 130 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 3 date entries
# Page 4/4: extracted 111 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 3 date entries
# Page 2/2: extracted 39 transactions so far
# Page 1/5: found 36 date entries
# Page 1/5: extracted 75 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 111 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 147 transactions so far
# Page 4/5: found 36 date entries
# Page 4/5: extracted 183 transactions so far
# Page 5/5: found 8 date entries
# Page 5/5: extracted 191 transactions so far
# Page 1/15: found 36 date entries
# Page 1/15: extracted 36 transactions so far
# Page 2/15: found 36 date entries
# Page 2/15: extracted 72 transactions so far
# Page 3/15: found 36 date entries
# Page 3/15: extracted 108 transactions so far
# Page 4/15: found 36 date entries
# Page 4/15: extracted 144 transactions so far
# Page 5/15: found 36 date entries
# Page 5/15: extracted 180 transactions so far
# Page 6/15: found 36 date entries
# Page 6/15: extracted 216 transactions so far
# Page 7/15: found 36 date entries
# Page 7/15: extracted 252 transactions so far
# Page 8/15: found 36 date entries
# Page 8/15: extracted 288 transactions so far
# Page 9/15: found 36 date entries
# Page 9/15: extracted 324 transactions so far
# Page 10/15: found 36 date entries
# Page 10/15: extracted 360 transactions so far
# Page 11/15: found 36 date entries
# Page 11/15: extracted 396 transactions so far
# Page 12/15: found 36 date entries
# Page 12/15: extracted 432 transactions so far
# Page 13/15: found 36 date entries
# Page 13/15: extracted 468 transactions so far
# Page 14/15: found 34 date entries
# Page 14/15: extracted 502 transactions so far
# Page 15/15: found 1 date entries
# Page 15/15: extracted 503 transactions so far
# Page : found 0 date entries
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 4 date entries
# Page 2/2: extracted 40 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 4 date entries
# Page 4/4: extracted 112 transactions so far
# Page 1/12: found 36 date entries
# Page 1/12: extracted 36 transactions so far
# Page 2/12: found 36 date entries
# Page 2/12: extracted 72 transactions so far
# Page 3/12: found 36 date entries
# Page 3/12: extracted 108 transactions so far
# Page 4/12: found 36 date entries
# Page 4/12: extracted 144 transactions so far
# Page 5/12: found 36 date entries
# Page 5/12: extracted 180 transactions so far
# Page 6/12: found 36 date entries
# Page 6/12: extracted 216 transactions so far
# Page 7/12: found 36 date entries
# Page 7/12: extracted 252 transactions so far
# Page 8/12: found 36 date entries
# Page 8/12: extracted 288 transactions so far
# Page 9/12: found 36 date entries
# Page 9/12: extracted 324 transactions so far
# Page 10/12: found 36 date entries
# Page 10/12: extracted 360 transactions so far
# Page 11/12: found 36 date entries
# Page 11/12: extracted 396 transactions so far
# Page 12/12: found 26 date entries
# Page 12/12: extracted 422 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 9 date entries
# Page 3/3: extracted 81 transactions so far
# Page 1/4: found 36 date entries
# Page 1/4: extracted 36 transactions so far
# Page 2/4: found 36 date entries
# Page 2/4: extracted 72 transactions so far
# Page 3/4: found 36 date entries
# Page 3/4: extracted 108 transactions so far
# Page 4/4: found 7 date entries
# Page 4/4: extracted 115 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 3 date entries
# Page 3/3: extracted 75 transactions so far
# Page 1/5: found 36 date entries
# Page 1/5: extracted 36 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 72 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 108 transactions so far
# Page 4/5: found 36 date entries
# Page 4/5: extracted 144 transactions so far
# Page 5/5: found 7 date entries
# Page 5/5: extracted 151 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 4 date entries
# Page 2/2: extracted 40 transactions so far
# Page 1/5: found 36 date entries
# Page 1/5: extracted 36 transactions so far
# Page 2/5: found 36 date entries
# Page 2/5: extracted 72 transactions so far
# Page 3/5: found 36 date entries
# Page 3/5: extracted 108 transactions so far
# Page 4/5: found 33 date entries
# Page 4/5: extracted 141 transactions so far
# Page 5/5: found 1 date entries
# Page 5/5: extracted 142 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 16 date entries
# Page 3/3: extracted 88 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 34 date entries
# Page 5/6: extracted 178 transactions so far
# Page 6/6: found 1 date entries
# Page 6/6: extracted 179 transactions so far
# Page : found 0 date entries
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 13 date entries
# Page 6/6: extracted 193 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 18 date entries
# Page 2/2: extracted 54 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 30 date entries
# Page 2/2: extracted 66 transactions so far
# Page 1/23: found 36 date entries
# Page 1/23: extracted 36 transactions so far
# Page 2/23: found 36 date entries
# Page 2/23: extracted 72 transactions so far
# Page 3/23: found 36 date entries
# Page 3/23: extracted 108 transactions so far
# Page 4/23: found 36 date entries
# Page 4/23: extracted 144 transactions so far
# Page 5/23: found 36 date entries
# Page 5/23: extracted 180 transactions so far
# Page 6/23: found 36 date entries
# Page 6/23: extracted 216 transactions so far
# Page 7/23: found 36 date entries
# Page 7/23: extracted 252 transactions so far
# Page 8/23: found 36 date entries
# Page 8/23: extracted 288 transactions so far
# Page 9/23: found 36 date entries
# Page 9/23: extracted 324 transactions so far
# Page 10/23: found 36 date entries
# Page 10/23: extracted 360 transactions so far
# Page 11/23: found 36 date entries
# Page 11/23: extracted 396 transactions so far
# Page 12/23: found 36 date entries
# Page 12/23: extracted 432 transactions so far
# Page 13/23: found 36 date entries
# Page 13/23: extracted 468 transactions so far
# Page 14/23: found 36 date entries
# Page 14/23: extracted 504 transactions so far
# Page 15/23: found 36 date entries
# Page 15/23: extracted 540 transactions so far
# Page 16/23: found 36 date entries
# Page 16/23: extracted 576 transactions so far
# Page 17/23: found 36 date entries
# Page 17/23: extracted 612 transactions so far
# Page 18/23: found 36 date entries
# Page 18/23: extracted 648 transactions so far
# Page 19/23: found 36 date entries
# Page 19/23: extracted 684 transactions so far
# Page 20/23: found 36 date entries
# Page 20/23: extracted 720 transactions so far
# Page 21/23: found 36 date entries
# Page 21/23: extracted 756 transactions so far
# Page 22/23: found 36 date entries
# Page 22/23: extracted 792 transactions so far
# Page 23/23: found 2 date entries
# Page 23/23: extracted 794 transactions so far
# Page : found 0 date entries
# Page 1/23: found 36 date entries
# Page 1/23: extracted 36 transactions so far
# Page 2/23: found 36 date entries
# Page 2/23: extracted 72 transactions so far
# Page 3/23: found 36 date entries
# Page 3/23: extracted 108 transactions so far
# Page 4/23: found 36 date entries
# Page 4/23: extracted 144 transactions so far
# Page 5/23: found 36 date entries
# Page 5/23: extracted 180 transactions so far
# Page 6/23: found 36 date entries
# Page 6/23: extracted 216 transactions so far
# Page 7/23: found 36 date entries
# Page 7/23: extracted 252 transactions so far
# Page 8/23: found 36 date entries
# Page 8/23: extracted 288 transactions so far
# Page 9/23: found 36 date entries
# Page 9/23: extracted 324 transactions so far
# Page 10/23: found 36 date entries
# Page 10/23: extracted 360 transactions so far
# Page 11/23: found 36 date entries
# Page 11/23: extracted 396 transactions so far
# Page 12/23: found 36 date entries
# Page 12/23: extracted 432 transactions so far
# Page 13/23: found 36 date entries
# Page 13/23: extracted 468 transactions so far
# Page 14/23: found 36 date entries
# Page 14/23: extracted 504 transactions so far
# Page 15/23: found 36 date entries
# Page 15/23: extracted 540 transactions so far
# Page 16/23: found 36 date entries
# Page 16/23: extracted 576 transactions so far
# Page 17/23: found 36 date entries
# Page 17/23: extracted 612 transactions so far
# Page 18/23: found 36 date entries
# Page 18/23: extracted 648 transactions so far
# Page 19/23: found 36 date entries
# Page 19/23: extracted 684 transactions so far
# Page 20/23: found 36 date entries
# Page 20/23: extracted 720 transactions so far
# Page 21/23: found 36 date entries
# Page 21/23: extracted 756 transactions so far
# Page 22/23: found 36 date entries
# Page 22/23: extracted 792 transactions so far
# Page 23/23: found 17 date entries
# Page 23/23: extracted 809 transactions so far
# Page 1/1: found 28 date entries
# Page 1/1: extracted 28 transactions so far
# Page 1/8: found 36 date entries
# Page 1/8: extracted 36 transactions so far
# Page 2/8: found 36 date entries
# Page 2/8: extracted 72 transactions so far
# Page 3/8: found 36 date entries
# Page 3/8: extracted 108 transactions so far
# Page 4/8: found 36 date entries
# Page 4/8: extracted 144 transactions so far
# Page 5/8: found 36 date entries
# Page 5/8: extracted 180 transactions so far
# Page 6/8: found 36 date entries
# Page 6/8: extracted 216 transactions so far
# Page 7/8: found 36 date entries
# Page 7/8: extracted 252 transactions so far
# Page 8/8: found 13 date entries
# Page 8/8: extracted 265 transactions so far
# Page 1/1: found 14 date entries
# Page 1/1: extracted 14 transactions so far
# Page : found 25 date entries
# Page : extracted 39 transactions so far
# Page : found 23 date entries
# Page : extracted 62 transactions so far
# Page : found 25 date entries
# Page : extracted 87 transactions so far
# Page : found 25 date entries
# Page : extracted 112 transactions so far
# Page : found 25 date entries
# Page : extracted 137 transactions so far
# Page : found 23 date entries
# Page : extracted 160 transactions so far
# Page 1/14: found 36 date entries
# Page 1/14: extracted 36 transactions so far
# Page 2/14: found 36 date entries
# Page 2/14: extracted 72 transactions so far
# Page 3/14: found 36 date entries
# Page 3/14: extracted 108 transactions so far
# Page 4/14: found 36 date entries
# Page 4/14: extracted 144 transactions so far
# Page 5/14: found 36 date entries
# Page 5/14: extracted 180 transactions so far
# Page 6/14: found 36 date entries
# Page 6/14: extracted 216 transactions so far
# Page 7/14: found 36 date entries
# Page 7/14: extracted 252 transactions so far
# Page 8/14: found 36 date entries
# Page 8/14: extracted 288 transactions so far
# Page 9/14: found 36 date entries
# Page 9/14: extracted 324 transactions so far
# Page 10/14: found 36 date entries
# Page 10/14: extracted 360 transactions so far
# Page 11/14: found 36 date entries
# Page 11/14: extracted 396 transactions so far
# Page 12/14: found 36 date entries
# Page 12/14: extracted 432 transactions so far
# Page 13/14: found 36 date entries
# Page 13/14: extracted 468 transactions so far
# Page 14/14: found 11 date entries
# Page 14/14: extracted 479 transactions so far
# Page : found 0 date entries
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 35 date entries
# Page 5/6: extracted 179 transactions so far
# Page 6/6: found 1 date entries
# Page 6/6: extracted 180 transactions so far
# Page 1/9: found 36 date entries
# Page 1/9: extracted 36 transactions so far
# Page 2/9: found 36 date entries
# Page 2/9: extracted 72 transactions so far
# Page 3/9: found 36 date entries
# Page 3/9: extracted 108 transactions so far
# Page 4/9: found 36 date entries
# Page 4/9: extracted 144 transactions so far
# Page 5/9: found 36 date entries
# Page 5/9: extracted 180 transactions so far
# Page 6/9: found 36 date entries
# Page 6/9: extracted 216 transactions so far
# Page 7/9: found 36 date entries
# Page 7/9: extracted 252 transactions so far
# Page 8/9: found 36 date entries
# Page 8/9: extracted 288 transactions so far
# Page 9/9: found 27 date entries
# Page 9/9: extracted 315 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 2 date entries
# Page 2/2: extracted 38 transactions so far
# Page 1/6: found 36 date entries
# Page 1/6: extracted 36 transactions so far
# Page 2/6: found 36 date entries
# Page 2/6: extracted 72 transactions so far
# Page 3/6: found 36 date entries
# Page 3/6: extracted 108 transactions so far
# Page 4/6: found 36 date entries
# Page 4/6: extracted 144 transactions so far
# Page 5/6: found 36 date entries
# Page 5/6: extracted 180 transactions so far
# Page 6/6: found 20 date entries
# Page 6/6: extracted 200 transactions so far
# Page 1/2: found 33 date entries
# Page 1/2: extracted 33 transactions so far
# Page 2/2: found 0 date entries
# Page 1/2: found 33 date entries
# Page 1/2: extracted 66 transactions so far
# Page 2/2: found 0 date entries
# Page 1/8: found 36 date entries
# Page 1/8: extracted 36 transactions so far
# Page 2/8: found 36 date entries
# Page 2/8: extracted 72 transactions so far
# Page 3/8: found 36 date entries
# Page 3/8: extracted 108 transactions so far
# Page 4/8: found 36 date entries
# Page 4/8: extracted 144 transactions so far
# Page 5/8: found 36 date entries
# Page 5/8: extracted 180 transactions so far
# Page 6/8: found 36 date entries
# Page 6/8: extracted 216 transactions so far
# Page 7/8: found 36 date entries
# Page 7/8: extracted 252 transactions so far
# Page 8/8: found 28 date entries
# Page 8/8: extracted 280 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 25 date entries
# Page 3/3: extracted 97 transactions so far
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 25 date entries
# Page : extracted 122 transactions so far
# Page : found 25 date entries
# Page : extracted 147 transactions so far
# Page : found 25 date entries
# Page : extracted 172 transactions so far
# Page : found 25 date entries
# Page : extracted 197 transactions so far
# Page : found 25 date entries
# Page : extracted 222 transactions so far
# Page : found 20 date entries
# Page : extracted 242 transactions so far
# Page : found 25 date entries
# Page : extracted 267 transactions so far
# Page : found 25 date entries
# Page : extracted 292 transactions so far
# Page : found 25 date entries
# Page : extracted 317 transactions so far
# Page : found 25 date entries
# Page : extracted 342 transactions so far
# Page : found 25 date entries
# Page : extracted 367 transactions so far
# Page : found 25 date entries
# Page : extracted 392 transactions so far
# Page : found 6 date entries
# Page : extracted 398 transactions so far
# Page : found 25 date entries
# Page : extracted 423 transactions so far
# Page : found 13 date entries
# Page : extracted 436 transactions so far
# Page : found 25 date entries
# Page : extracted 461 transactions so far
# Page : found 25 date entries
# Page : extracted 486 transactions so far
# Page : found 25 date entries
# Page : extracted 511 transactions so far
# Page : found 25 date entries
# Page : extracted 536 transactions so far
# Page : found 25 date entries
# Page : extracted 561 transactions so far
# Page : found 2 date entries
# Page : extracted 563 transactions so far
# Page : found 25 date entries
# Page : extracted 588 transactions so far
# Page : found 25 date entries
# Page : extracted 613 transactions so far
# Page : found 25 date entries
# Page : extracted 638 transactions so far
# Page : found 3 date entries
# Page : extracted 641 transactions so far
# Page : found 25 date entries
# Page : extracted 666 transactions so far
# Page : found 25 date entries
# Page : extracted 691 transactions so far
# Page : found 25 date entries
# Page : extracted 716 transactions so far
# Page : found 25 date entries
# Page : extracted 741 transactions so far
# Page : found 9 date entries
# Page : extracted 750 transactions so far
# Page 1/1: found 19 date entries
# Page 1/1: extracted 19 transactions so far
# Page 1/3: found 36 date entries
# Page 1/3: extracted 36 transactions so far
# Page 2/3: found 36 date entries
# Page 2/3: extracted 72 transactions so far
# Page 3/3: found 6 date entries
# Page 3/3: extracted 78 transactions so far
# Page 1/2: found 36 date entries
# Page 1/2: extracted 36 transactions so far
# Page 2/2: found 32 date entries
# Page 2/2: extracted 68 transactions so far
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page : found 0 date entries
# Page 1/25: found 36 date entries
# Page 1/25: extracted 36 transactions so far
# Page 2/25: found 36 date entries
# Page 2/25: extracted 72 transactions so far
# Page 3/25: found 36 date entries
# Page 3/25: extracted 108 transactions so far
# Page 4/25: found 36 date entries
# Page 4/25: extracted 144 transactions so far
# Page 5/25: found 36 date entries
# Page 5/25: extracted 180 transactions so far
# Page 6/25: found 36 date entries
# Page 6/25: extracted 216 transactions so far
# Page 7/25: found 36 date entries
# Page 7/25: extracted 252 transactions so far
# Page 8/25: found 36 date entries
# Page 8/25: extracted 288 transactions so far
# ...
# 108988-02031829-2566_1_BBL.pdf    247613.56  247613.56                True     246114.32   246114.32                 True               64.0             181.0             181               64                           True                            True
# 108988-02032050-2566_1_BBL.pdf     71224.61   71224.61                True      57005.73    57005.73                 True                5.0             140.0             140                5                           True                            True
# 108988-02032093-2566_1_BBL.pdf    348403.06  348403.06                True     354459.69   354459.69                 True              349.0             517.0             517              349                           True                            True
# 108988-02032125-2566_1_BBL.pdf    110294.60  110294.60                True     102987.62   102987.62                 True                9.0             128.0             128                9                           True                            True
# 108988-02032864-2566_1_BBL.pdf     66635.00   66635.00                True      65432.40    65432.40                 True               10.0             110.0             110               10                           True                            True
# 108988-02032917-2566_1_BBL.pdf    317967.39  317967.39                True     306628.02   306628.02                 True               62.0             284.0             284               62                           True                            True
# 108988-02032921-2566_1_BBL.pdf    138411.49  138411.49                True     137234.65   137234.65                 True               15.0              76.0              76               15                           True                            True
# 108988-02033020-2566_1_BBL.pdf     74649.00   74649.00                True      72314.96    72314.96                 True                5.0              35.0              35                5                           True                            True
# 108988-02033093-2566_1_BBL.pdf   1359793.84 1359793.84                True    1359648.91  1359648.91                 True              518.0            1003.0            1003              518                           True                            True
# 108988-02033185-2566_1_BBL.pdf    118860.25  118860.25                True     113651.35   113651.35                 True               34.0              79.0              79               34                           True                            True
# 108988-02033234-2566_1_BBL.pdf    826824.86  826824.86                True     827116.52   827116.52                 True              501.0            1030.0            1030              501                           True                            True
# 108988-02033490-2566_1_BBL.pdf    207138.28  207138.28                True     205822.13   205822.13                 True              166.0             258.0             258              166                           True                            True
# 108988-02033784-2566_1_BBL.pdf     71410.11   71410.11                True      67952.77    67952.77                 True                9.0              30.0              30                9                           True                            True
# 108988-02033818-2566_1_BBL.pdf    209777.46  209777.46                True     159019.91   159019.91                 True                6.0             393.0             393                6                           True                            True
# 108988-02033868-2566_1_BBL.pdf    362772.77  362772.77                True     359227.09   359227.09                 True               17.0             172.0             172               17                           True                            True
# 108988-02033887-2566_1_BBL.pdf    108920.16  108920.16                True     108920.61   108920.61                 True               65.0             155.0             155               65                           True                            True
# 108988-02033888-2566_1_BBL.pdf    396431.38  396431.38                True     371060.15   371060.15                 True               68.0             303.0             303               68                           True                            True
# 108988-02033961-2566_1_BBL.pdf    743643.41  743643.41                True     724981.85   724981.85                 True               11.0             134.0             134               11                           True                            True
# 108988-02034078-2566_1_BBL.pdf    525186.54  525186.54                True     525186.09   525186.09                 True              219.0             616.0             616              219                           True                            True
# 108988-02034309-2566_1_BBL.pdf    125728.02  125728.02                True     125616.27   125616.27                 True              129.0             163.0             163              129                           True                            True
# 108988-02034444-2566_1_BBL.pdf    374130.93  374130.93                True     343219.96   343219.96                 True              130.0             304.0             304              130                           True                            True
# 108988-02034548-2566_1_BBL.pdf     66021.85   66021.85                True      65771.85    65771.85                 True                5.0              31.0              31                5                           True                            True
# 108988-02034622-2566_1_BBL.pdf    251087.96  251087.96                True     250425.64   250425.64                 True               81.0             761.0             761               81                           True                            True
# 108988-02034733-2566_1_BBL.pdf     98533.80   98533.80                True      76533.06    76533.06                 True                6.0             194.0             194                6                           True                            True
# 108988-02034833-2566_1_BBL.pdf    333540.00  333540.00                True     333569.00   333569.00                 True                6.0               6.0               6                6                           True                            True
# 108988-02034934-2566_1_BBL.pdf   1016272.52 1016272.52                True     999529.44   999529.44                 True              215.0             656.0             656              215                           True                            True
# 108988-02035070-2566_1_BBL.pdf     63362.65   63362.65                True      66103.58    66103.58                 True               38.0             138.0             138               38                           True                            True
# 108988-02035287-2566_1_BBL.pdf     90708.00   90708.00                True      87814.69    87814.69                 True               45.0             150.0             150               45                           True                            True
# 108988-02035316-2566_1_BBL.pdf    307455.14  307455.14                True     279605.40   279605.40                 True              106.0             263.0             263              106                           True                            True
# 108988-02035393-2566_1_BBL.pdf    447164.00  447164.00                True     447563.95   447563.95                 True              218.0             877.0             877              218                           True                            True
# 108988-02035404-2566_1_BBL.pdf    214019.27  214019.27                True     194795.69   194795.69                 True               16.0             124.0             124               16                           True                            True
# 108988-02035541-2566_1_BBL.pdf    119818.36  119818.36                True     109394.63   109394.63                 True               65.0             136.0             136               65                           True                            True
# 108988-02035674-2566_1_BBL.pdf    119795.90  119795.90                True     119789.53   119789.53                 True               29.0              78.0              78               29                           True                            True
# 108988-02035731-2566_1_BBL.pdf    136942.96  136942.96                True     127333.04   127333.04                 True               15.0             124.0             124               15                           True                            True
# 108988-02035814-2566_1_BBL.pdf    216904.39  216904.39                True     226904.93   226904.93                 True               12.0              41.0              41               12                           True                            True
# 108988-02035976-2566_1_BBL.pdf    100786.86  100786.86                True     100786.86   100786.86                 True               11.0              39.0              39               11                           True                            True
# 108988-02036036-2566_1_BBL.pdf    128391.37  128391.37                True     127585.81   127585.81                 True               27.0              47.0              47               27                           True                            True
# 108988-02036091-2566_1_BBL.pdf    118741.78  118741.78                True     130041.42   130041.42                 True               52.0              96.0              96               52                           True                            True
# 108988-02036219-2566_1_BBL.pdf    796324.37  796324.37                True     795525.26   795525.26                 True              104.0             213.0             213              104                           True                            True
# 108988-02036425-2566_1_BBL.pdf   1043340.01 1043340.01                True     998198.55   998198.55                 True               62.0             202.0             202               62                           True                            True
# 108988-02036605-2566_1_BBL.pdf    164136.80  164136.80                True     190269.08   190269.08                 True               15.0              20.0              20               15                           True                            True
# 108988-02036978-2566_1_BBL.pdf     88875.85   88875.85                True      88691.65    88691.65                 True               32.0             117.0             117               32                           True                            True
# 108988-02037018-2566_1_BBL.pdf    128660.64  128660.64                True     128719.21   128719.21                 True               13.0              64.0              64               13                           True                            True
# 108988-02037117-2566_1_BBL.pdf    152755.82  152755.82                True     154757.76   154757.76                 True               15.0             108.0             108               15                           True                            True
# 108988-02037160-2566_1_BBL.pdf     53042.94   53042.94                True      48969.93    48969.93                 True                9.0              85.0              85                9                           True                            True
# 108988-02067152-2566_1_BBL.pdf    188168.00  188168.00                True     186196.83   186196.83                 True               13.0             121.0             121               13                           True                            True
# 108988-02405739-2566_1_BBL.pdf    283454.98  283454.98                True     286410.42   286410.42                 True               51.0             684.0             684               51                           True                            True
#         scan43723467246372.pdf     62325.00   62325.00                True      62324.83    62324.83                 True               23.0              44.0              44               23                           True                            True
#             มีbankอื่นปก 4.pdf    116799.00  116799.00                True     110615.56   110615.56                 True                4.0              29.0              29                4                           True                            True
#               มีbankอื่นปน.pdf    568098.53  568098.53                True     563400.09   563400.09                 True               85.0             260.0             260               85                           True                            True
#             มีscanu2783824.pdf    184597.00  184597.00                True     188617.11   188617.11                 True               88.0             332.0             332               88                           True                            True
#                    มีscbปน.pdf     96212.53  361330.71               False      85172.55  1713216.32                False               35.0              67.0             452              419                          False                           False
#                   มีscbปน2.pdf     52595.00  193814.14               False      52595.02    52595.02                 True                6.0               7.0             153                6                          False                            True
#                  มีรูปถ่าย.pdf    250976.37  250976.37                True     328275.50   328275.50                 True              216.0             209.0             209              216                           True                            True
#                   มีรูปแคป.pdf    257830.26  996966.47               False     257797.43   257797.43                 True               19.0              77.0             730               19                          False                            True
#                     มีสแกน.pdf    102382.35  102382.35                True     102324.62   102324.62                 True               15.0             102.0             102               15                           True                            True
#            มีเอกสารอื่นปน4.pdf    515179.94  515179.94                True     514141.68   514141.68                 True              181.0             338.0             338              181                           True                            True
#           มีเอกสารอื่นปน88.pdf    251595.18  251595.18                True     252921.51   252921.51                 True              123.0             272.0             272              123                           True                            True
#
# ❌ Files with mismatches:
#         file  total_debit  sum_debit  debit_amount_match  total_credit  sum_credit  credit_amount_match  total_credit_txns  total_debit_txns  count_debit_tx  count_credit_tx  transaction_count_debit_match  transaction_count_credit_match  diff_debit  diff_credit
#  มีscbปน.pdf     96212.53  361330.71               False      85172.55  1713216.32                False               35.0              67.0             452              419                          False                           False   265118.18 1.628044e+06
# มีscbปน2.pdf     52595.00  193814.14               False      52595.02    52595.02                 True                6.0               7.0             153                6                          False                            True   141219.14 7.275958e-12
# มีรูปแคป.pdf    257830.26  996966.47               False     257797.43   257797.43                 True               19.0              77.0             730               19                          False                            True   739136.21 0.000000e+00

# %%
summary
# Out:
#                                file  total_debit  sum_debit  \
# 0    108988-02009141-2566_1_BBL.pdf    478572.75  478572.75
# 1    108988-02009467-2566_1_BBL.pdf    707682.26  707682.26
# 2    108988-02009558-2566_1_BBL.pdf    519756.79  519756.79
# 3    108988-02009782-2566_3_BBL.pdf     57072.89   57072.89
# 4    108988-02009839-2566_1_BBL.pdf    393083.29  393083.29
# ..                              ...          ...        ...
# 284                   มีรูปถ่าย.pdf    250976.37  250976.37
# 285                    มีรูปแคป.pdf    257830.26  996966.47
# 286                      มีสแกน.pdf    102382.35  102382.35
# 287             มีเอกสารอื่นปน4.pdf    515179.94  515179.94
# 288            มีเอกสารอื่นปน88.pdf    251595.18  251595.18
#
#      debit_amount_match  total_credit  sum_credit  credit_amount_match  \
# 0                  True     478619.38   478619.38                 True
# 1                  True     706536.75   706536.75                 True
# 2                  True     519700.46   519700.46                 True
# 3                  True      47087.89    47087.89                 True
# 4                  True     393118.90   393118.90                 True
# ..                  ...           ...         ...                  ...
# 284                True     328275.50   328275.50                 True
# 285               False     257797.43   257797.43                 True
# 286                True     102324.62   102324.62                 True
# 287                True     514141.68   514141.68                 True
# 288                True     252921.51   252921.51                 True
#
#      total_credit_txns  total_debit_txns  count_debit_tx  count_credit_tx  \
# 0                340.0            1183.0            1183              340
# 1                148.0             797.0             797              148
# 2                291.0             392.0             392              291
# 3                  5.0              29.0              29                5
# 4                140.0             304.0             304              140
# ..                 ...               ...             ...              ...
# 284              216.0             209.0             209              216
# 285               19.0              77.0             730               19
# 286               15.0             102.0             102               15
# 287              181.0             338.0             338              181
# 288              123.0             272.0             272              123
#
#      transaction_count_debit_match  transaction_count_credit_match
# 0                             True                            True
# 1                             True                            True
# 2                             True                            True
# 3                             True                            True
# 4                             True                            True
# ..                             ...                             ...
# 284                           True                            True
# 285                          False                            True
# 286                           True                            True
# 287                           True                            True
# 288                           True                            True
#
# [289 rows x 13 columns]

# %%
bad
# Out:
#              file  total_debit  sum_debit  debit_amount_match  total_credit  \
# 282   มีscbปน.pdf     96212.53  361330.71               False      85172.55
# 283  มีscbปน2.pdf     52595.00  193814.14               False      52595.02
# 285  มีรูปแคป.pdf    257830.26  996966.47               False     257797.43
#
#      sum_credit  credit_amount_match  total_credit_txns  total_debit_txns  \
# 282  1713216.32                False               35.0              67.0
# 283    52595.02                 True                6.0               7.0
# 285   257797.43                 True               19.0              77.0
#
#      count_debit_tx  count_credit_tx  transaction_count_debit_match  \
# 282             452              419                          False
# 283             153                6                          False
# 285             730               19                          False
#
#      transaction_count_credit_match  diff_debit   diff_credit
# 282                           False   265118.18  1.628044e+06
# 283                            True   141219.14  7.275958e-12
# 285                            True   739136.21  0.000000e+00

# %%
failures
# Out:
# []

# %%
df_tx_all
# Out:
#       page_id       date time description channel   debit  credit  balance  \
# 0         1/5 2023-03-03                   mPhone   250.0     NaN   2450.3
# 1         1/5 2023-03-04                   mPhone   300.0     NaN   2150.3
# 2         1/5 2023-03-04                   mPhone    20.0     NaN   2130.3
# 3         1/5 2023-03-04                   mPhone    20.0     NaN   2110.3
# 4         1/5 2023-03-05                   mPhone   100.0     NaN   2010.3
# ...       ...        ...  ...         ...     ...     ...     ...      ...
# 84476     6/6 2023-08-02                   ATMoth   800.0     NaN      0.5
# 84477     6/6 2023-08-07                   mPhone     NaN  2000.0   2000.5
# 84478     6/6 2023-08-07                   mPhone   500.0     NaN   1500.5
# 84479     6/6 2023-08-07                   mPhone   500.0     NaN   1000.5
# 84480     6/6 2023-08-07                   mPhone  1000.0     NaN      0.5
#
#       transaction_type                     source_file
# 0        PMT FOR GOODS  108988-02024502-2566_1_BBL.pdf
# 1       PMT. PROMPTPAY  108988-02024502-2566_1_BBL.pdf
# 2       TRF. PROMPTPAY  108988-02024502-2566_1_BBL.pdf
# 3       PMT. PROMPTPAY  108988-02024502-2566_1_BBL.pdf
# 4       TRF. PROMPTPAY  108988-02024502-2566_1_BBL.pdf
# ...                ...                             ...
# 84476     CASH ATM W/D  108988-02023058-2566_2_BBL.pdf
# 84477    TRF FR OTH BK  108988-02023058-2566_2_BBL.pdf
# 84478    TRF TO OTH BK  108988-02023058-2566_2_BBL.pdf
# 84479    TRF TO OTH BK  108988-02023058-2566_2_BBL.pdf
# 84480    TRF TO OTH BK  108988-02023058-2566_2_BBL.pdf
#
# [84481 rows x 10 columns]

# %%
df_hdr_all
# Out:
#      page_id          account_name account_number                   period  \
# 0        1/5   นาย ธนากร อุนจิตต  087-7-56931-9  01/03/2023 - 16/08/2023
# 1        2/5   นาย ธนากร อุนจิตต  087-7-56931-9  01/03/2023 - 16/08/2023
# 2        3/5   นาย ธนากร อุนจิตต  087-7-56931-9  01/03/2023 - 16/08/2023
# 3        4/5   นาย ธนากร อุนจิตต  087-7-56931-9  01/03/2023 - 16/08/2023
# 4        5/5   นาย ธนากร อุนจิตต  087-7-56931-9  01/03/2023 - 16/08/2023
# ...      ...                   ...            ...                      ...
# 2504     2/6  นาย พิพัฒพงค กมลผัน  068-8-11675-5  01/05/2023 - 18/08/2023
# 2505     3/6  นาย พิพัฒพงค กมลผัน  068-8-11675-5  01/05/2023 - 18/08/2023
# 2506     4/6  นาย พิพัฒพงค กมลผัน  068-8-11675-5  01/05/2023 - 18/08/2023
# 2507     5/6  นาย พิพัฒพงค กมลผัน  068-8-11675-5  01/05/2023 - 18/08/2023
# 2508     6/6  นาย พิพัฒพงค กมลผัน  068-8-11675-5  01/05/2023 - 18/08/2023
#
#       total_debit_transaction  total_debit  total_credit_transaction  \
# 0                         NaN          NaN                       NaN
# 1                         NaN          NaN                       NaN
# 2                         NaN          NaN                       NaN
# 3                         NaN          NaN                       NaN
# 4                       127.0    102104.33                      18.0
# ...                       ...          ...                       ...
# 2504                      NaN          NaN                       NaN
# 2505                      NaN          NaN                       NaN
# 2506                      NaN          NaN                       NaN
# 2507                      NaN          NaN                       NaN
# 2508                    168.0    116700.80                      26.0
#
#       total_credit address                     source_file
# 0              NaN          108988-02024502-2566_1_BBL.pdf
# 1              NaN          108988-02024502-2566_1_BBL.pdf
# 2              NaN          108988-02024502-2566_1_BBL.pdf
# 3              NaN          108988-02024502-2566_1_BBL.pdf
# 4         99404.03          108988-02024502-2566_1_BBL.pdf
# ...            ...     ...                             ...
# 2504           NaN          108988-02023058-2566_2_BBL.pdf
# 2505           NaN          108988-02023058-2566_2_BBL.pdf
# 2506           NaN          108988-02023058-2566_2_BBL.pdf
# 2507           NaN          108988-02023058-2566_2_BBL.pdf
# 2508     114367.50          108988-02023058-2566_2_BBL.pdf
#
# [2509 rows x 10 columns]
